# %% [markdown]
# **Brian Blaylock**
# *April 14, 2021*
#
# ![image.png](attachment:19a520b0-927e-4305-9503-e6e5b2bd37b5.png)
#
# # Sesame Street Gang
# Having some fun learning how to write python classes. Each character is it's own class with attributes for catch phrase, and colors based on the Sesame Street style guide. There is also a class for the whole gang with methods to show colors of different body parts.

# %%
from sesame_street import elmo, ernie, bigBird, gang

# %%
elmo
# Out:
# My name is Elmo. Elmo is so happy to see you!

# %%
print(elmo)
# Out:
# self.name='Elmo'
# self.catch_phrase='Elmo is so happy to see you!'
# self.colors={'body': '#EF3340', 'mouth': '#000000', 'nose': '#FF8200'}
# self.friends={'Dorthy': 'Goldfish', 'David': 'Monster Toy', 'Mr.Noodle': 'Human'}

# %%
bigBird.show_colors()

# %%
print(elmo)
# Out:
# self.name='Elmo'
# self.catch_phrase='Elmo is so happy to see you!'
# self.colors={'body': '#EF3340', 'mouth': '#000000', 'nose': '#FF8200'}
# self.friends={'Dorthy': 'Goldfish', 'David': 'Monster Toy', 'Mr.Noodle': 'Human'}

# %%
# Default will get body colors
gang().get_colors()
# Out:
# {'Zoe': '#F1B434',
#  'Rosita': '#3CDBC0',
#  'Oscar the Grouch': '#84BD00',
#  'Grover': '#0072CE',
#  'Elmo': '#EF3340',
#  'Count Von Count': '#CAA2DD',
#  'Cookie Monter': '#0085CA',
#  'Bert': '#FFD100',
#  'Ernie': '#FF8200',
#  'Big Bird': '#FFD100'}

# %%
gang().show_colors()

# %%
gang().show_colors('tongue')

# %%
gang().show_colors('nose')

# %%
gang().show_colors('mouth')
